# %%
# Import dependencies for streaming tweets
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

# For saving tweets to database
import sqlite3

# For sentiment analysis
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# Additional
import json
from unidecode import unidecode
import time

# %%
# Import info for Twitter API
from config import access_token_key, access_token_secret, consumer_key, consumer_secret

# %%
# Set up sentiment analyzer
sentiment_analyzer = SentimentIntensityAnalyzer()

# %%
# Set up database which tweets can be stored in
# Create SQLite database and table
# We will track tweet sentiment, tweet text, and time of tweet
conn = sqlite3.connect('PoliticsPredicted6.db')
c = conn.cursor()

def create_table():
    try:
        c.execute("CREATE TABLE IF NOT EXISTS TwitterDB(unix REAL, tweet TEXT, sentiment REAL)")
        c.execute("CREATE INDEX fast_unix ON TwitterDB(unix)")
        c.execute("CREATE INDEX fast_tweet ON TwitterDB(tweet)")
        c.execute("CREATE INDEX fast_sentiment ON TwitterDB(sentiment)")
        conn.commit()
    except Exception as e:
        print(str(e))

create_table()

# %%
# Set up a live stream of all tweets; track and store tweets using this script, run second script to filter
# Use the polarity_scores() method to get the sentiment metrics for a piece of text
# Avoid filtering and tracking dynamically to avoid repeatedly breaking our connection to Twitter
# Include error handling
class listener(StreamListener):
    def on_data(self, data):
        
        try:
            data = json.loads(data)
                     
            tweet = unidecode(data['text'])
            time_ms = data['timestamp_ms']
            vader_sentiment = sentiment_analyzer.polarity_scores(tweet)
            sentiment = vader_sentiment['compound']
            
            print(sentiment, tweet, time)
            c.execute('INSERT INTO TwitterDB (unix, sentiment, tweet) VALUES (?, ?, ?)',
                        (time_ms, sentiment, tweet))
            conn.commit()
            
        except KeyError as e:
            print(str(e))
        return(True)
    
    def on_error(self, status):
        print(status)

# Track vowels to capture all words (all tweets)
while True:
    try:
        auth = OAuthHandler(consumer_key, consumer_secret)
        auth.set_access_token(access_token_key, access_token_secret)
        twitterStream = Stream(auth, listener())
        twitterStream.filter(track=["@realDonaldTrump", "Donald Trump", "President Trump"])
        # Avoid only using 'trump' to avoid overfitting, i.e. ace trump etc.
    
    except Exception as e:
        print(str(e))
        time.sleep(5)
        
        # Code to truncate or reset database to avoid saved data overload
# Out:
# 0.34 RT @NicolasMaduro: Trataron de tapar con un concierto y una supuesta "ayuda humanitaria" en la frontera, un plan que ha sido develado y anu... <module 'time' (built-in)>
# 0.0 RT @tedlieu: Last Nov, @GOP campaigned on the Wall of @realDonaldTrump. Dems campaigned on healthcare, infrastructure &amp; rooting out corrupt... <module 'time' (built-in)>
# -0.2263 RT @JohnTrumpFanKJV: Lord, Please place an impenetrable hedge of protection around President Trump. Set his enemies in slippery places. May... <module 'time' (built-in)>
# 0.7027 RT @OliverMcGee: WOW @POTUS @realDonaldTrump! I just discovered @ElbertGuillory's 2012 video, when he announced he was leaving the Democrat... <module 'time' (built-in)>
# 0.0 RT @teleSURtv: #ULTIMOMINUTO | Presidente de #EEUU, @realDonaldTrump , anuncia que aplazara el aumento de los aranceles a los productos chi... <module 'time' (built-in)>
# -0.5932 RT @Education4Libs: Dear libs,
#
# I don't remember congressional approval for the $1.7 billion Obama sent to a country that chants "death to... <module 'time' (built-in)>
# 0.0 .[?]@realDonaldTrump[?] Emilee stumps for #Trump https://t.co/dkJvJY9Y7E <module 'time' (built-in)>
# 0.7906 @realDonaldTrump Great job potus, and much better than anything the dems have acomplished in the last decade <module 'time' (built-in)>
# 0.0772 Trump is President, Where's My New Sisters of Mercy Album?  https://t.co/fu3D4Gcuga via @hprocksoff. I missed this... https://t.co/iSI2383gRV <module 'time' (built-in)>
# 0.0 RT @Airvooocht: @realDonaldTrump I wonder if Donald Trump will salute a North Korean general again? https://t.co/UMmbUP7mC1 <module 'time' (built-in)>
# 0.0 @realDonaldTrump Obama has nothing on you, Mr. President! <module 'time' (built-in)>
# 0.0 @JohnCornyn @SenatorCollins https://t.co/HIhS8Ycxme
#
# Where does the fossil fuel come from? Fracking?   Can we get... https://t.co/EAs3VL0tJX <module 'time' (built-in)>
# 0.0 RT @ChatByCC: @realDonaldTrump Liberal and globalists heads are exploding everywhere at the thought of a Summit for President Xi and Presid... <module 'time' (built-in)>
# 0.9473 RT @tibbs_cindy: Thank You, President Trump, for making this holiday bigger &amp; better than ever before! And yes, YOU ARE THE BEST PRESIDENT... <module 'time' (built-in)>
# -0.8126 RT @GOP: "Under my Administration, the African-American poverty rate has fallen to its lowest level." -@realDonaldTrump https://t.co/wkebFY... <module 'time' (built-in)>
# 0.34 RT @PresidencialVen: #DeInteres  | "El plan esta develado, lo ha anunciado Donald Trump desde la Casa Blanca que el esta contemplando una... <module 'time' (built-in)>
# 0.6971 @GOPChairwoman @realDonaldTrump Don't forget that this sieved at the port of entry. The border patrol is doing a great job without the wall. <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# -0.5574 @Fahrenthold @GlennKesslerWP @realDonaldTrump Illegal. Learn how to spell. <module 'time' (built-in)>
# 0.2942 RT @JamesWStork: Do you believe Donald Trump belongs in prison? Please RT. Thanks! <module 'time' (built-in)>
# -0.2263 @realDonaldTrump No we want your tax returns. <module 'time' (built-in)>
# 0.8979 RT @ECHOtheCALL: I'm loving this
#
# This is the best question to ask
# Alexa
#
# Who is the President of United States?
#
#  Donald Trump ... <module 'time' (built-in)>
# -0.3612 RT @ProudResister: -- A Trump supporter says he "might have to kill" a black man.
#
# -- A Trump supporter calls female protestors "fuckin' whor... <module 'time' (built-in)>
# 0.0 @realDonaldTrump Finally a President that's working for us and not a all talk do nothing Democrat! <module 'time' (built-in)>
# -0.357 RT @Mr_MAGA1776: They said we didn't have a chance in the 2016 election
#
# They say we don't have a chance in the 2020 election.
#
# Will you v... <module 'time' (built-in)>
# 0.7065 RT @Bruce_LeVell: [?]@realDonaldTrump[?] Approval Soars -- Despite Media Attacks - The Daily Caller  https://t.co/ACisu68efL <module 'time' (built-in)>
# 0.0 @robertadams7007 @TampaBayAJ @jasonhaber @RachelMoreaux @atworkbarby @GregShugar @realDonaldTrump Obama did better... https://t.co/BDkc1nBCJz <module 'time' (built-in)>
# 0.34 @432hzFreq @steph93065 @LovecleFrank @DonTollman @Patriot_MM @cmclymer @AOC @RepAOC President Trump is solving a lo... https://t.co/1AFeAnBYGX <module 'time' (built-in)>
# 0.5423 RT @rgoodlaw: What continues to amaze is DOJ "policy"--keeping secret derogatory information on people who aren't indicted--applies to crimin... <module 'time' (built-in)>
# 0.0 RT @Fahrenthold: This is at least the 2nd time @realDonaldTrump has recorded a video for a Mar-a-Lago banquet. He also did it for the PB Po... <module 'time' (built-in)>
# 0.0 RT @RobertoCarlo14: Para los que me han preguntado:
#
# Creo que la salida final sera un ultimatum publico d USA pero a traves de Donald Trump... <module 'time' (built-in)>
# -0.5932 RT @Education4Libs: Dear libs,
#
# I don't remember congressional approval for the $1.7 billion Obama sent to a country that chants "death to... <module 'time' (built-in)>
# 0.0 RT @ReneeCarrollAZ: @realDonaldTrump #LockHerUp https://t.co/Onk34wZg0t <module 'time' (built-in)>
# 0.0 @whartonone @koaleszenz @charliekirk11 @realDonaldTrump But those goods sold to China will put more money into the... https://t.co/g73E7dqcFX <module 'time' (built-in)>
# 0.5574 Donald Trump, Gay-Rights Hero | Trending https://t.co/ziYz0OIueC <module 'time' (built-in)>
# -0.4404 RT @perlmutations: President Of C Block. https://t.co/kxfDMFvoCG <module 'time' (built-in)>
# 0.0 @PressSec @realDonaldTrump Remember, kids - when voting in elections:
#
# D for Democrat
#
# R for Russian <module 'time' (built-in)>
# -0.4404 RT @perlmutations: President Of C Block. https://t.co/kxfDMFvoCG <module 'time' (built-in)>
# 0.6249 RT @DoingRight1: Donald Trump's "I am with you"  Great motivational speech from @POTUS.
#
# @DoingRight1 follows back all #MAGA #KAG https://... <module 'time' (built-in)>
# 0.0 @realDonaldTrump @POTUS https://t.co/UlanS1CmQ2 <module 'time' (built-in)>
# 0.0516 @realDonaldTrump But...what can you celebrate if America is having a national emergency?  Did u forget we have an e... https://t.co/gmeZpE5JyB <module 'time' (built-in)>
# 0.8225 RT @AngrierWHStaff: DC already does the National Independence Day Parade, which is awesome.
#
# Bonus: Trump doesn't speak at the parade.
#
# Cho... <module 'time' (built-in)>
# -0.5106 RT @DemocraticShift: @realDonaldTrump Is this a reinvention of your failed military parade? <module 'time' (built-in)>
# -0.2755 RT @MSNBC: Former CIA Director John Brennan: "Mr.Trump is a deeply flawed individual, who I think has demonstrated that he is not fit to se... <module 'time' (built-in)>
# 0.0 Spottpreis: #DonaldTrump raumt bei #GoldenerHimbeere ab https://t.co/wceFIZyOnQ A #Razzie for @RealDonaldTrump. So... https://t.co/qWc0QT4Yq2 <module 'time' (built-in)>
# 0.0 RT @SCMPNews: Donald Trump and Kim Jong-un are just days away from their second meeting. Here's what you need to know. #TrumpKimSummit http... <module 'time' (built-in)>
# 0.7845 RT @ACTBrigitte: Leave it to the anti-American left to make fun of President Trump for wanting to throw an amazing 4th of July event.
#
# They... <module 'time' (built-in)>
# 0.0 RT @JeraldTroyLaub: President Trump Takes Bold Steps To Fight for the Unborn - 1600 Daily https://t.co/KUWeDi9sXO <module 'time' (built-in)>
# 0.0 @realDonaldTrump  @SaraCarterDC
# @JudicialWatch  @seanhannity <module 'time' (built-in)>
# 0.0 RT @TomFitton: Will @AdamSchiff testify about his  and his party's "collusion" with Fusion GPS to overthrow @RealDonaldTrump?  https://t.co... <module 'time' (built-in)>
# 0.0 RT @davidaxelrod: Half century later, @realDonaldTrump finally is headed to Vietnam in the service of his country! <module 'time' (built-in)>
# -0.4404 UNITED STATES PRESIDENT DONALD TRUMP EXECUTIVE ORDER'S MURDER HIM FOR US, KU KLUCK KLAN LEADER DAVID DUKE SAID GET... https://t.co/vBis93G48v <module 'time' (built-in)>
# 0.5429 RT @UROCKlive1: @realDonaldTrump Oh. OK. So absolutely no progress will be made once again, and you'll come home and brag about how you're... <module 'time' (built-in)>
# 0.3612 @MaxAbrahms Thank you
# https://t.co/fwrXiAC1Lx <module 'time' (built-in)>
# 0.0 RT @Trumpbane1969: @NewerEra @HollisDockins @RichGarver @Ana_Ssassin47 @maga_divawife @dcmark4 @Nicole09729523 @TexSunDancer @TomasiMpishi... <module 'time' (built-in)>
# 0.4404 @JeffreyGuterman @realDonaldTrump Trump supporters can't understand those big words...you will have to draw pictures <module 'time' (built-in)>
# 0.0 RT @BolsonaroSP: Inesperadamente fui chamado pela anfitria Toni Kramer, uma das maiores apoiadoras de @realDonaldTrump nos EUA, para fala... <module 'time' (built-in)>
# -0.6421 RT @ROCKONOHIO: Hey #ShiftySchiff I don't trust you! You want 2 bring down #PresidentTrump at all cost! Instead why don't you help Presiden... <module 'time' (built-in)>
# 0.4019 RT @teleSURtv: #ENVIDEO | Cientos de personas marchan en la ciudad de #NuevaYork, #EEUU en favor de la revolucion Bolivariana y en rechaz... <module 'time' (built-in)>
# -0.4633 @EdKrassen @realDonaldTrump Why should we be allowed to have nukes but they can't?  Would you agree if the table were turned? <module 'time' (built-in)>
# -0.8176 RT @mmpadellan: Actually, Orange Mussolini already HAD half a chance (2 bullshit years):
#
# LOCKED BABIES IN CAGES
# Fake national emergency
# Em... <module 'time' (built-in)>
# 0.1531 RT @next_china: Chinese stocks jumped at the open after Donald Trump postponed the date for boosting tariffs on Chinese imports https://t.c... <module 'time' (built-in)>
# 0.6114 RT @ConservativePTZ: Bailey loves President Trump! https://t.co/57eLc2aoqZ <module 'time' (built-in)>
# 0.3818 RT @Rosauraaaaa1: People don't understand that planned parenthood didn't just focus on abortions it focused on birth control, std tests, &amp;... <module 'time' (built-in)>
# -0.4404 RT @perlmutations: President Of C Block. https://t.co/kxfDMFvoCG <module 'time' (built-in)>
# 0.0 @realDonaldTrump @DonaldJTrumpJr @FoxNews @CNN @SpeakerPelosi @chuckschumer @KamalaHarris @RepMaxineWaters @MSNBC... https://t.co/VRlK6syu8E <module 'time' (built-in)>
# -0.236 @realDonaldTrump FUCKING KISS ASS! <module 'time' (built-in)>
# 0.3182 RT @MicheleDTweets: Hear what @RyanHillMI said @realDonaldTrump? The only attendees at your #FourthofYouLie ceremony (I'm sure you'll crown... <module 'time' (built-in)>
# -0.7414 RT @tedwheeler: The President's manufactured national emergency pales in comparison to the very real threat of climate change. I fully supp... <module 'time' (built-in)>
# 0.0 RT @GrassrootsSpeak: Donald Trump...
#
# The man behind the Art of the Deal....
#
# ...can't manage to buy 50 cents for $500,000
#
# Sounds about r... <module 'time' (built-in)>
# 0.0 @realDonaldTrump Who TF is Graham Ledger? <module 'time' (built-in)>
# -0.6523 RT @DrDenaGrayson: @JRubinBlogger @jaketapper Alex Acosta's ILLEGAL plea deal for Jeffrey Epstein also provides #immunity for his co-conspi... <module 'time' (built-in)>
# 0.0 RT @KyungLahCNN: Here's @KamalaHarris' response to my question in her Iowa press gaggle to @realDonaldTrump's tweet announcing a parade &amp; f... <module 'time' (built-in)>
# -0.5994 RT @MaxBlumenthal: Note that while Republican leadership and Trump called on @IlhanMN to resign for criticizing the Israeli apartheid lobby... <module 'time' (built-in)>
# -0.5106 RT @leahbolger: @ProudResister @realDonaldTrump I felt sick watching this and I didn't even have the sound on.  Where does all of this vehe... <module 'time' (built-in)>
# -0.2771 RT @KAG4All: .Read this!
# 7 Shocking Statistics on Immigration.
# National #BorderCrisis is real.
# President Trump protects us.
# Of 110K in pris... <module 'time' (built-in)>
# -0.5574 RT @RBReich: When the public fires a president before Election Day, they don't send him a letter telling him he's fired. They just make him... <module 'time' (built-in)>
# -0.3865 @krassenstein @realDonaldTrump Your not even a very good PAID shill https://t.co/shCDdQiLcr <module 'time' (built-in)>
# 0.0 @dcexaminer @realDonaldTrump https://t.co/3kMKVNro2a <module 'time' (built-in)>
# -0.5932 RT @Education4Libs: Dear libs,
#
# I don't remember congressional approval for the $1.7 billion Obama sent to a country that chants "death to... <module 'time' (built-in)>
# 0.34 Yeah to keep from giving it to Trump.....the Gov. needs to stop it and make him return the money....How can a perso... https://t.co/SxflX6D0C6 <module 'time' (built-in)>
# 0.34 RT @NicolasMaduro: Trataron de tapar con un concierto y una supuesta "ayuda humanitaria" en la frontera, un plan que ha sido develado y anu... <module 'time' (built-in)>
# -0.5574 RT @EdKrassen: Hillary Clinton loses emails and Republicans chant "Lock her up".
#
# Donald Trump loses children and Republicans chant "Four M... <module 'time' (built-in)>
# 0.4588 @realDonaldTrump My favorite President is Obama. <module 'time' (built-in)>
# -0.6249 RT @SecPompeo: Spoke to @JakeTapper on @CNNSotu today. We discussed the Venezuela crisis and, in advance of the Hanoi Summit, @realDonaldTr... <module 'time' (built-in)>
# 0.0 @realDonaldTrump @STAND_For_FLAG_ https://t.co/PCruYu6SnA <module 'time' (built-in)>
# -0.296 @realDonaldTrump You're announcing your resignation? <module 'time' (built-in)>
# 0.0 RT @RepMattGaetz: These elements with Manafort largely arise before Donald Trump ran for President or so far after Manafort's departure the... <module 'time' (built-in)>
# -0.1646 RT @firstcoastind: @KrisBrbr93 @PastorDScott @ChampkinsFox @realDonaldTrump Couldn't agree more, God Bless you and your family!! <module 'time' (built-in)>
# 0.0772 RT @charliekirk11: California is suing Donald Trump over his decision to spend 6.6 Billion dollars to secure our border and Finish the Wall... <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/tPPhUw58sQ <module 'time' (built-in)>
# 0.0 RT @itsJeffTiedrich: @realDonaldTrump isn't it disrespectful of you to be tweeting from church? oh that's right, you don't go to church. hmm <module 'time' (built-in)>
# 0.4767 RT @Glass__Steagall: @GeorgePapa19 British intelligence organized Russiagate in collaboration with Brennan and company because Trump threat... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.0 RT @usa_is_free: @42Gnome @DVCMAC @gabe_seabass @AzDreamin2 @TrueReality9 @LizEClark @randallpink17 @BigThingzzz @FaceMchorse @KKatMiss @ro... <module 'time' (built-in)>
# 0.1154 An oldie but a goodie about America's number one baddie https://t.co/Ulw2xR5DMq <module 'time' (built-in)>
# 0.4588 @JoesGuy @gmoylan @JGalt_Dagny @minniefirst @realDonaldTrump If you think that there is any noble cause, then you a... https://t.co/re6G6WsUbm <module 'time' (built-in)>
# 0.0 @realDonaldTrump
# @JerryMoran
# @MikeCrapo
# @SenateGOP
# @SenSchumer
# @SenWarren
# @SenSanders
# @SpeakerPelosi... https://t.co/hPahmEay11 <module 'time' (built-in)>
# -0.4215 RT @GOPChairwoman: Thanks to @realDonaldTrump, we're eliminating bad trade deals with foreign countries and China is no exception.
#
# China... <module 'time' (built-in)>
# 0.1531 RT @next_china: Chinese stocks jumped at the open after Donald Trump postponed the date for boosting tariffs on Chinese imports https://t.c... <module 'time' (built-in)>
# 0.3724 @ZoltanVarga1903 @ChatByCC @realDonaldTrump Nope your wrong <module 'time' (built-in)>
# 0.7257 So true! They are more concerned about getting work than having values, ethics etc <module 'time' (built-in)>
# -0.636 RT @LindaSuhler: @realDonaldTrump Obama was on a path to war with NK and you have turned this around--thank you, President Trump!  Maybe if... <module 'time' (built-in)>
# 0.0 @CNNPolitics not a bully&gt;
# "Bernie Sanders goes on to say: "Trump will not talk about how he is the first president... https://t.co/fqRIZi2EhF <module 'time' (built-in)>
# 0.1027 RT @SahaisleyKelly: The latest target of their fury quite literally has them seeing red - the Make America Great Again baseball cap created... <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# -0.5574 RT @EdKrassen: Hillary Clinton loses emails and Republicans chant "Lock her up".
#
# Donald Trump loses children and Republicans chant "Four M... <module 'time' (built-in)>
# 0.0 @realDonaldTrump Where are your TAX RETURNS ??? <module 'time' (built-in)>
# 0.25 RT @RedPillBlackMan: Cnn, dream on baby. @realDonaldTrump will be president for 8 years. Let that sink in. https://t.co/9hWsfaBw0G <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.5267 RT @AdamSchiff: The Justice Department cannot take the position that a sitting president can't be indicted, and at the same time withhold e... <module 'time' (built-in)>
# -0.0516 RT @davereaboi: I think he should get together with his national security apparatus and try to destroy his successor. Maybe concoct phony "... <module 'time' (built-in)>
# 0.4767 RT @sarahkendzior: "Donald Trump is friends with at least five pedophiles, most of whom were involved in sex trafficking or blackmail schem... <module 'time' (built-in)>
# -0.8316 RT @GKeile: JUSSIE ll
#
# Malcolm Nance said on MSNBC
# that President Trump sent secret attack orders to the Coast Guard terrorist.
#
# This man... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.2023 @realDonaldTrump "I disagree," said a scowling Trump, causing top Chinese negotiator Vice Premier Liu He to laugh.... https://t.co/JGlWpPo7nH <module 'time' (built-in)>
# 0.0 RT @MaihenH: PETICION | ?Apoyarian una intervencion de EEUU en Venezuela que permita sacar a Maduro de Miraflores?. Me pueden ayudar para q... <module 'time' (built-in)>
# -0.6155 Bernie Sanders ATTACKED on Fox News after Presidential bid - it's 'EXTREME socialism!' https://t.co/EPpGvhY83I <module 'time' (built-in)>
# -0.296 RT @Pang_a_lang: @RepJeffries Also me and my wife get an extra $580/month from tax cuts. Our return was also more then last year, which was... <module 'time' (built-in)>
# -0.5719 RT @TomFitton: MASSIVE @JudicialWatch Update:  Lawsuit to Expose Coup Against @RealDonaldTrump, Another FBI Cover-up of potential Clinton e... <module 'time' (built-in)>
# -0.8316 RT @GKeile: JUSSIE ll
#
# Malcolm Nance said on MSNBC
# that President Trump sent secret attack orders to the Coast Guard terrorist.
#
# This man... <module 'time' (built-in)>
# -0.5267 RT @trashytrashrat: @realDonaldTrump So far, Donald has spent $7.7 billion dollars of our tax money paying off farmers hurt by his idiotic... <module 'time' (built-in)>
# -0.5574 RT @charliekirk11: Obama said these are "dangerous times"
#
# He is lying, again
#
# Facts:
#
# Thanks to
# @realDonaldTrump
#  world has never been s... <module 'time' (built-in)>
# -0.34 RT @WalshFreedom: A question that should bother all Americans:
#
# Why has President Trump never wanted to get to the bottom of what Russia di... <module 'time' (built-in)>
# -0.5815 RT @jb_anon: Trump Takes Back $1 Billion from California; Gavin Newsom Complains!! Anons!!
# (link: https://t.co/otj0Pg4Kqb) https://t.co/JAs... <module 'time' (built-in)>
# -0.296 RT @davidfrum: Trump wants to be at the center of all events ... yet for some reason he has refused every invitation to throw out the first... <module 'time' (built-in)>
# 0.4023 @PressSec @realDonaldTrump Prove it.  Your word means nothing.  Trump is a liar. <module 'time' (built-in)>
# 0.0 RT @glennkirschner2: All the signs are there that Barr will make the right call for the country. I understand there are countervailing fact... <module 'time' (built-in)>
# -0.5719 RT @TomFitton: MASSIVE @JudicialWatch Update:  Lawsuit to Expose Coup Against @RealDonaldTrump, Another FBI Cover-up of potential Clinton e... <module 'time' (built-in)>
# 0.4199 @realDonaldTrump Thank you Mr. President! This has needed to be done for so long and you are accomplishing it. <module 'time' (built-in)>
# -0.5267 RT @laradiodelsur: En 2017 Donald Trump le dijo a su director del FBI Andrew McCabe: "No entiendo, ?por que no estamos en guerra con Venezu... <module 'time' (built-in)>
# 0.9661 RT @DiamondandSilk: Enjoyed chatting with our great President, @realDonaldTrump. We love &amp; support the @POTUS because he loves &amp; supports a... <module 'time' (built-in)>
# 0.2732 @HenryMerrilees @Imamofpeace @SickOfTheSwamp @IlhanMN @realDonaldTrump Well, she has an accent, so from my standpoi... https://t.co/a0zr4Iy4kR <module 'time' (built-in)>
# 0.2942 RT @JamesWStork: Do you believe Donald Trump belongs in prison? Please RT. Thanks! <module 'time' (built-in)>
# 0.2003 RT @RyanHillMI: @chrisfamousamos @realDonaldTrump You Guys Must be Tired of all the Winning!
#
# https://t.co/vSKSCyeVC2 <module 'time' (built-in)>
# 0.34 RT @SykesCharlie: "A bipartisan group of 58 former senior national security officials will issue a statement Monday saying that "there is n... <module 'time' (built-in)>
# -0.5267 @jaarreaza @guver2008 @SecPompeo Titiritero @RealDonaldTrump Hijo de puta criminal. Y Sus marionetas:
# @IvanDuque... https://t.co/OnAjBEIqsr <module 'time' (built-in)>
# 0.0 RT @laineymel: @realDonaldTrump @RealJamesWoods @DonaldJTrumpJr
# #Venezuela
# Look at THAT  https://t.co/8f4CEPZ9Nt <module 'time' (built-in)>
# 0.0 Contemporary politics with my Jidu. (Grandpa in Arabic)
#
# @realDonaldTrump #politics #politicalsatire https://t.co/VVBKE9ucUa <module 'time' (built-in)>
# 0.8979 RT @ECHOtheCALL: I'm loving this
#
# This is the best question to ask
# Alexa
#
# Who is the President of United States?
#
#  Donald Trump ... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.5106 @krassenstein @realDonaldTrump Is this trolling tweet for free or were you for sale on this one also? <module 'time' (built-in)>
# 0.0 @RandellW410 @itsJeffTiedrich @realDonaldTrump Not mine. <module 'time' (built-in)>
# 0.659 RT @PressSec: President @realDonaldTrump delivers more great news for our farmers. https://t.co/ACq0ujTFTS <module 'time' (built-in)>
# 0.4278 RT @adjunctprofessr: Remember.
# You owe it to your country.
# To yourself.
# To your children.
# We stand with you.
# The time is now.
# FOR GOD &amp; COU... <module 'time' (built-in)>
# 0.0 We should be in jail <module 'time' (built-in)>
# -0.7644 @realDonaldTrump You lying muppet. You suck at everything! <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# -0.296 RT @davidfrum: Trump wants to be at the center of all events ... yet for some reason he has refused every invitation to throw out the first... <module 'time' (built-in)>
# -0.0015 RT @mmpadellan: @ProudResister @realDonaldTrump Who among us cannot fondly recall, hearts swelling with pride, the legions of people at Oba... <module 'time' (built-in)>
# 0.8793 RT @Bruce_LeVell: Happy Presidents Day ! [?]@realDonaldTrump[?]   The greatest [?]@POTUS[?] in the history of the USA . https://t.co/lCabvGyT42 <module 'time' (built-in)>
# -0.2235 @DiamondandSilk @realDonaldTrump @POTUS Just because he doesn't kiss your ass doesn't mean he isn't a good president. <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# -0.5859 swear someone needs to ban tea @realDonaldTrump  get on this <module 'time' (built-in)>
# -0.296 RT @JEM_Books: #TWGPS
#
# And that is exactly what he should do. President Trump is no simpleton. He sees the writing on the wall. Democra... <module 'time' (built-in)>
# 0.0 Let's do it again on 2020 <module 'time' (built-in)>
# 0.0 RT @ForeverLogical: @realDonaldTrump https://t.co/jPkNS5ndDR <module 'time' (built-in)>
# 0.4404 @realDonaldTrump What have you accomplished? Be specific and don't lie. <module 'time' (built-in)>
# -0.296 RT @GOPChairwoman: Unbelievable.
#
# Democrats are now attacking @realDonaldTrump for sending humanitarian aid to the Venezuelan people.
# http... <module 'time' (built-in)>
# -0.6808 RT @RyanAFournier: Time to hear all of the Hollywood elite complain about how oppressed they are under President Trump.  #TheOscars <module 'time' (built-in)>
# 0.34 RT @SykesCharlie: "A bipartisan group of 58 former senior national security officials will issue a statement Monday saying that "there is n... <module 'time' (built-in)>
# -0.6808 RT @RyanAFournier: Time to hear all of the Hollywood elite complain about how oppressed they are under President Trump.  #TheOscars <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# 0.0 RT @ProfesSocialis: Senado de Nueva Jersey aprueba ley que dejaria a Trump fuera de las elecciones: https://t.co/N0QDKH5T6v Ya vemos la des... <module 'time' (built-in)>
# -0.296 RT @davidfrum: Trump wants to be at the center of all events ... yet for some reason he has refused every invitation to throw out the first... <module 'time' (built-in)>
# 0.0 RT @pastormarkburns: Congress is extremely disrespectful for having Michael Cohen testify before Congress on the same day as the historic p... <module 'time' (built-in)>
# 0.0 Watch his eyes  <module 'time' (built-in)>
# 0.8271 RT @shanehardy58: BREAKING......
# The Oscar Award  for the greatest POTUS in American history goes to...... @realDonaldTrump
#  #B... <module 'time' (built-in)>
# 0.0 RT @eleonorabruzual: @marcorubio @USAenEspanol @usembassyve @realDonaldTrump @Almagro_OEA2015 @SecPompeo @VP La rata inmunda @DrodriguezVen... <module 'time' (built-in)>
# 0.3182 RT @gracy69epixnet: Asking everyone to pray for President TrumpJesus,Encamp your guardian angels around
# President Trump&amp;all traveling   t... <module 'time' (built-in)>
# 0.0 RT @Fahrenthold: This is at least the 2nd time @realDonaldTrump has recorded a video for a Mar-a-Lago banquet. He also did it for the PB Po... <module 'time' (built-in)>
# -0.5106 RT @krassenstein: If Obama, the Black President, had 5 children w/ 3 wives, cheated on all 3 wives, one with a porn star after his wife jus... <module 'time' (built-in)>
# 0.0 RT @Joy_Villa: @realDonaldTrump I'll be there!  <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/gmXYb5DKmE <module 'time' (built-in)>
# 0.7845 RT @ACTBrigitte: Leave it to the anti-American left to make fun of President Trump for wanting to throw an amazing 4th of July event.
#
# They... <module 'time' (built-in)>
# -0.296 #FueraGuaidoDeColombia larguese con su guerra para Miami, los colombianos no vamos a luchar por sus cobardes compat... https://t.co/pOHy14mhnn <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.7768 RT @PinkBelgium: Awesome News ! Suburban Women Are Very Important For The Re-Election In 2020!  #Trump2020 #MAGA @realDonaldTrump - "Re... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/fnMHzXBVA5 <module 'time' (built-in)>
# -0.7229 Are we in the #twilightzone #rbg the movie??? Wtf? Even #JenniferHudson  sang flat on an on the fly theme! #Oscars... https://t.co/usm5uTx3F1 <module 'time' (built-in)>
# -0.3182 RT @TheLastRefuge2: Yup...  there it is.  Tariff delay and confirmed Panda summit immediately upon return from Trump Kim meeting.
#
# [long... <module 'time' (built-in)>
# 0.0 RT @TrumpOrBust2020: Trump said on Feb. 24 he would delay an increase in U.S. tariffs on Chinese goods scheduled for later this week thanks... <module 'time' (built-in)>
# 0.8979 RT @ECHOtheCALL: I'm loving this
#
# This is the best question to ask
# Alexa
#
# Who is the President of United States?
#
#  Donald Trump ... <module 'time' (built-in)>
# 0.7519 RT @QsentMeToo: GREAT TO SEE PEOPLE WAKING UP!! https://t.co/sysQ8TRT5X <module 'time' (built-in)>
# 0.0 @realDonaldTrump Get real, unreal man <module 'time' (built-in)>
# 0.0 RT @JohnFugelsang: Guys Donald Trump just decreed that this year's 4th of July may also be referred to as Independence Day.
#
# He's also go... <module 'time' (built-in)>
# -0.8176 RT @mmpadellan: Actually, Orange Mussolini already HAD half a chance (2 bullshit years):
#
# LOCKED BABIES IN CAGES
# Fake national emergency
# Em... <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# -0.296 @realDonaldTrump @Robin1762 How about a wall and stop your son-in- law run our country into the ground with his ant... https://t.co/qWjXKo8CRT <module 'time' (built-in)>
# 0.1511 they have all lost their liberal, triggered, snowflake minds! If Trump lost I'm sure he'd accept it. They really... https://t.co/Eaq1YL3ETU <module 'time' (built-in)>
# -0.6908 RT @CEasttwood: ANYONE who is says @realDonaldTrump should stop tweeting is an enemy of the state. How else are we going to know what the f... <module 'time' (built-in)>
# -0.6731 RT @Jamierodr14: .This is the most incredible display of the Dems getting the Election all wrong! They just don't get it and the BIAS media... <module 'time' (built-in)>
# 0.0 @joebloughed @ProudResister @Tiernimarie @joetstat @realDonaldTrump U N F I T https://t.co/22l0Xot2qL <module 'time' (built-in)>
# 0.0 RT @Fahrenthold: This is at least the 2nd time @realDonaldTrump has recorded a video for a Mar-a-Lago banquet. He also did it for the PB Po... <module 'time' (built-in)>
# -0.4588 RT @bmr0954: @RepCummings "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Ep... <module 'time' (built-in)>
# 0.8074 RT @mmpadellan: @realDonaldTrump TRANSLATION:
#
# I am pleased to report that the shit I fucked up myself with the trade wars (because I don't... <module 'time' (built-in)>
# 0.7081 RT @charliekirk11: WOW!
#
# Hundreds of young Latinos chant "BUILD THE WALL!" at @TPUSA
#
# These amazing leaders are SICK of open borders &amp; the... <module 'time' (built-in)>
# 0.0 RT @MaihenH: PETICION | ?Apoyarian una intervencion de EEUU en Venezuela que permita sacar a Maduro de Miraflores?. Me pueden ayudar para q... <module 'time' (built-in)>
# 0.5574 RT @evagolinger: It's all about the rich Venezuelans in Florida who go to Trump's clubs and give him money. These are the ones with influen... <module 'time' (built-in)>
# 0.34 RT @Avenger2Toxic: Diamond and Silk: Trump Did More for Blacks than 'Any Other President'
# https://t.co/bNI0xOg8iT <module 'time' (built-in)>
# 0.0 RT @WhiteHouse: Eight months ago, President Trump met with Chairman Kim Jong Un of North Korea in a historic moment for American diplomacy.... <module 'time' (built-in)>
# 0.7481 @realDonaldTrump WHY CANT IT BE AT THE WHITE HOUSE ASSHOLE? OHHHH U WANNA PLAY GOLF AND MAKE IT LOOK LIKE YOU ARE WORKING <module 'time' (built-in)>
# 0.3313 RT @PaulieD55: Donald Trump's chance of re-election in 2020 is:
#
# [?]Answer poll and retweet for larger sample size[?]
#
# #MAGA   <module 'time' (built-in)>
# -0.5562 RT @ProudResister: President of the prison yard! @DonaldJTrumpJr https://t.co/LaoAdSO0nU <module 'time' (built-in)>
# -0.3612 RT @PhilippeReines: 2nd year in a row @realDonaldTrump's too embarrassed to throw a ball. https://t.co/ty8xi04KWY <module 'time' (built-in)>
# 0.0 @realDonaldTrump @ScottMorrisonMP @Haspelina(Pt25)Frances Gardner,Yendi Jordan,Melissa Wilson,Nicole Dyer,Aliana So... https://t.co/6W6AsmHBpE <module 'time' (built-in)>
# -0.5574 RT @EdKrassen: Hillary Clinton loses emails and Republicans chant "Lock her up".
#
# Donald Trump loses children and Republicans chant "Four M... <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/4kSYdEI4AA <module 'time' (built-in)>
# 0.5859 RT @saradannerdukic: Wow, it's just a bottomless rabbit hole.  Guess who brokered the deal when Trump sold the Plaza to Al-Waleed bin Talal... <module 'time' (built-in)>
# 0.0 RT @lordprivacy: @WesSmith123 Because Donald J Trump is also involved...
#
# has been for their entire lives!
#
# https://t.co/As8JOL0Lkj <module 'time' (built-in)>
# 0.659 RT @PressSec: President @realDonaldTrump delivers more great news for our farmers. https://t.co/ACq0ujTFTS <module 'time' (built-in)>
# 0.0 @RyanHillMI @realDonaldTrump https://t.co/np9Ek8i1X4 <module 'time' (built-in)>
# -0.0018 how do u advocate low government control then try to make the most important decisions in someone life for them <module 'time' (built-in)>
# -0.5574 RT @charliekirk11: Obama said these are "dangerous times"
#
# He is lying, again
#
# Facts:
#
# Thanks to
# @realDonaldTrump
#  world has never been s... <module 'time' (built-in)>
# 0.7845 @Tate_Jo @GOPChairwoman @realDonaldTrump I wish he'd declare that air was the best thing ever. They'd all suffocate... https://t.co/Nidyhm4Dd3 <module 'time' (built-in)>
# 0.5267 RT @AdamSchiff: The Justice Department cannot take the position that a sitting president can't be indicted, and at the same time withhold e... <module 'time' (built-in)>
# 0.5994 @Shirley07487947 @realDonaldTrump So Trump tweets he wants be bff with Putin, says he'll get along great...
# With Pu... https://t.co/cDeETc9Jxm <module 'time' (built-in)>
# 0.7906 RT @HerbS97798467: @realDonaldTrump Great job potus, and much better than anything the dems have acomplished in the last decade <module 'time' (built-in)>
# 0.0 #unitednotdivided <module 'time' (built-in)>
# 0.4019 @JustinRWestgate @realDonaldTrump Yes.  And. <module 'time' (built-in)>
# 0.0 RT @JuanGuaiDog: #GuaidoNosTraicionaste . Que triste es reconocerlo . Mi  ridiculo  gobierno
#
# solo existe en #twitter e #instagram . En 1... <module 'time' (built-in)>
# 0.5106 RT @JoanofAmerica: @realDonaldTrump #truth #NorthKorea is Free [?] https://t.co/jPNXE9Mg9c <module 'time' (built-in)>
# 0.3612 RT @RNCastaldo: Let's roll the tapes again. It would be something if you retweeted this viral video of Obama sounding like @realDonaldTrump... <module 'time' (built-in)>
# 0.6289 RT @AnonymousInfo9: @AnonymousEagle4 @protrumpuk @realDonaldTrump  WE ARE WINNING BIGLY
# WE ARE DIRECTLY OVER THE TARGET ANON'S
#  KEEP DR... <module 'time' (built-in)>
# -0.7269 @realDonaldTrump You sound stupid, Hillary conspired against herself with Putin because she wanted to lose the Presidency to a buffoon. <module 'time' (built-in)>
# 0.0 @maxxx__power @will10459 @Gr82bMAGA @ProLifeTexanUSA @raymysterio305 @edwood_not @Marc751e2f95 @heyk1967... https://t.co/skxhvn7Nxk <module 'time' (built-in)>
# -0.1531 RT @RussOnPolitics: @kylegriffin1 White nationalism is a major threat to our nation's safety -- but people like Donald Trump turn a blind e... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.0772 RT @charliekirk11: California is suing Donald Trump over his decision to spend 6.6 Billion dollars to secure our border and Finish the Wall... <module 'time' (built-in)>
# 0.6166 RT @winstonCovfefe: This man works until 2 AM, and then sleeps only 4 hours.
# This man works for FREE, he gives away his salary quarterly.... <module 'time' (built-in)>
# -0.6808 RT @Brenderm1: @RealTrumpLady @realDonaldTrump And her husband's, son's, Hell the whole family. Since she's been using her position to get... <module 'time' (built-in)>
# -0.5618 RT @JoeBarri: How can anybody disagree with this? Why doesn't every woman demand control of her own body.  How can any man deny any woman t... <module 'time' (built-in)>
# 0.3612 @LindaSuhler @realDonaldTrump Agree <module 'time' (built-in)>
# 0.0 RT @davidaxelrod: Half century later, @realDonaldTrump finally is headed to Vietnam in the service of his country! <module 'time' (built-in)>
# 0.0 @realDonaldTrump @KatiePavlich Uh....no. <module 'time' (built-in)>
# 0.1531 RT @next_china: Chinese stocks jumped at the open after Donald Trump postponed the date for boosting tariffs on Chinese imports https://t.c... <module 'time' (built-in)>
# 0.6908 RT @1776Stonewall: @realDonaldTrump During the shutdown you gained 20 points with Hispanics, taking you to 51% approval with Hispanics. And... <module 'time' (built-in)>
# 0.7351 @realDonaldTrump Maybe you can remind the GOP senators (and strong supporters of you) that spent last July 4th in R... https://t.co/VxKzznIyMF <module 'time' (built-in)>
# 0.34 RT @SykesCharlie: "A bipartisan group of 58 former senior national security officials will issue a statement Monday saying that "there is n... <module 'time' (built-in)>
# 0.0772 RT @kenolin1: @realDonaldTrump You do realize you're the President of the United States and not just a 14 year old, un-loved, lonely, rich,... <module 'time' (built-in)>
# 0.3612 @realDonaldTrump He's writing comedy routines now.  <module 'time' (built-in)>
# 0.0 RT @MsAvaArmstrong: President @realDonaldTrump is the wall. <module 'time' (built-in)>
# 0.6369 @realDonaldTrump All time best MAGA <module 'time' (built-in)>
# 0.4019 "Everyone Is Smart, Except Donald Trump:" Rabbi Dov Fischer https://t.co/pmoy6TjWlJ <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/tNS7rrM0wu <module 'time' (built-in)>
# -0.7579 Democrats behaving badly.  A danger to society.
# @realDonaldTrump @HouseGOP @SenateGOP @seanhannity <module 'time' (built-in)>
# -0.6696 RT @GrahamLedger: The fascist left always attacks the truth! #fascist https://t.co/1CzpfKCaqg <module 'time' (built-in)>
# 0.3832 @EdKrassen @graffitiwriter1 @realDonaldTrump It is kind of funny though. <module 'time' (built-in)>
# -0.6731 RT @Jamierodr14: .This is the most incredible display of the Dems getting the Election all wrong! They just don't get it and the BIAS media... <module 'time' (built-in)>
# -0.3182 RT @TheLastRefuge2: Yup...  there it is.  Tariff delay and confirmed Panda summit immediately upon return from Trump Kim meeting.
#
# [long... <module 'time' (built-in)>
# 0.3612 Right now I'm watching the film  "The Pianist." The early days of the Nazis look just like what the GOP is doing to... https://t.co/kRUoEJEvpt <module 'time' (built-in)>
# 0.0 @realDonaldTrump There should never of been a case against Trump he's the best[?]It's deplorable &amp; despicable what t... https://t.co/RhPBwkcIX8 <module 'time' (built-in)>
# 0.0 @realDonaldTrump Fucking jabrone. <module 'time' (built-in)>
# 0.5267 RT @AdamSchiff: The Justice Department cannot take the position that a sitting president can't be indicted, and at the same time withhold e... <module 'time' (built-in)>
# 0.0 RT @AnnCoulter: I'm president of the Trump re-election campaign.  Other groups will make bumper stickers &amp; signs, but I'm the only one actu... <module 'time' (built-in)>
# 0.4215 RT @Cordicon: @TheSharpEdge1 lol Im going to use this in my next video
#
# Heres mine
# https://t.co/4WdW9Xccqm <module 'time' (built-in)>
# -0.5267 RT @garyg1884: Donald Trump Jr's comments that he's considering a run for President in 2024 shows the same level of arrogance as his father... <module 'time' (built-in)>
# -0.1027 RT @xIpsoFacto: @DrDenaGrayson @JRubinBlogger @jaketapper @realDonaldTrump Let's stop playing politics for a sec.
#
# If anybody is knowingly... <module 'time' (built-in)>
# -0.5106 @realDonaldTrump Liar. <module 'time' (built-in)>
# 0.3182 RT @RL9631: Please make it viral again... Retweet, retweet... https://t.co/KwMeBal8hT <module 'time' (built-in)>
# -0.8043 @realDonaldTrump STOP WASTING OUR MONEY!!! <module 'time' (built-in)>
# 0.0 RT @Shoriginals: Why are the #Oscars being presented in the @realDonaldTrump hair?#Oscars2019 https://t.co/McFesNtAsX <module 'time' (built-in)>
# 0.8268 @realDonaldTrump The president Xi of china has been very helpful to your daughter Ivanka awarding her special trade... https://t.co/M22cvQNBu8 <module 'time' (built-in)>
# 0.0 @thebradfordfile @realDonaldTrump YouTube SOTU <module 'time' (built-in)>
# 0.4926 RT @jjauthor: Liberals will believe anything! @realDonaldTrump won the popular vote. HilLIARy got 6 million ++ illegal votes from non-citiz... <module 'time' (built-in)>
# -0.8176 RT @mmpadellan: Actually, Orange Mussolini already HAD half a chance (2 bullshit years):
#
# LOCKED BABIES IN CAGES
# Fake national emergency
# Em... <module 'time' (built-in)>
# 0.6486 RT @KatTheHammer1: "Let Donald Trump know we are completely behind him, and may God give him strength to continue his calling."
#
# ~@jonvoigh... <module 'time' (built-in)>
# 0.0 RT @RealJack: BREAKING: President Trump Makes Americans An Extra $60B Annually In New Deal With China
#
# If Mainstream Media Can't Twist It,... <module 'time' (built-in)>
# -0.5932 RT @Education4Libs: Dear libs,
#
# I don't remember congressional approval for the $1.7 billion Obama sent to a country that chants "death to... <module 'time' (built-in)>
# 0.128 RT @PalmerReport: Donald Trump's day so far:
#
# - Claims he invented the 4th of July
# - Attacks the FBI
# - Praises Kim Jong Un
# - Marco Rubio ca... <module 'time' (built-in)>
# 0.0772 RT @charliekirk11: California is suing Donald Trump over his decision to spend 6.6 Billion dollars to secure our border and Finish the Wall... <module 'time' (built-in)>
# -0.6124 RT @itsJeffTiedrich: @realDonaldTrump "what if the stupidest criminal on the planet became the united states president" is not a question a... <module 'time' (built-in)>
# 0.4435 RT @StumpforTrump: GREAT AGAIN: @realDonaldTrump Just Scored A MAJOR Victory With China, But The Media Is Staying Quiet https://t.co/Rc2Z0i... <module 'time' (built-in)>
# -0.5255 @charliekirk11 @realDonaldTrump These ARE dangerous times!  The Leftist mob is doing everything they can to regain... https://t.co/kRkyWJd9Fg <module 'time' (built-in)>
# -0.5848 @FlowerNoman @warriordaisy @ScottDa11666529 @realDonaldTrump Boomer curse words! <module 'time' (built-in)>
# -0.2263 @dcexaminer @realDonaldTrump Was she in drag? <module 'time' (built-in)>
# 0.7089 RT @GregShugar: @realDonaldTrump Sounds fun and highly original. Shall we call this July 4th day "Independence Day"? <module 'time' (built-in)>
# -0.802 RT @jjauthor: I don't think the people of Venezuela are fighting any ghosts - their misery and hunger are real. https://t.co/s4zIM7thhU <module 'time' (built-in)>
# 0.68 Dear @realDonaldTrump
# I've never been one to wish that America would intervene in another country...until now! Thi... https://t.co/Zk9SgJ53ZZ <module 'time' (built-in)>
# -0.4588 RT @bmr0954: @realDonaldTrump "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr... <module 'time' (built-in)>
# -0.5574 @realDonaldTrump Your still in the White House. You were fired by the people of America. We need to eliminate hate... https://t.co/WoKKN6Q8LL <module 'time' (built-in)>
# -0.1027 RT @nickie_greer: Screw you. Besides, we won't have to find out. https://t.co/XvXTOz5nDF <module 'time' (built-in)>
# -0.128 RT @silver_fox9: Typical fake news reporting. The real question is will the DimocRATS, @TheDemocrats , accept a Trump landslide in 2020.
# #F... <module 'time' (built-in)>
# 0.296 RT @ToxDocCSO: Yep https://t.co/yACW1L7GaN <module 'time' (built-in)>
# 0.2846 RT @itsJeffTiedrich: @realDonaldTrump well ok, Putin asked it, but he didn't really expect to get an answer <module 'time' (built-in)>
# 0.4753 RT @joncoopertweets: HOLD THE DATE! We will be having the biggest celebration in the history of the United States on the day @realDonaldTru... <module 'time' (built-in)>
# 0.4767 How low we have sunk as a country and as people. So far removed from the late 60s and 70s that was a time of love a... https://t.co/epOlXCz5EK <module 'time' (built-in)>
# 0.6696 @realDonaldTrump Donald, more than 200 million Americans hope and pray that you stay in Hanoi, forever plus a day!... https://t.co/PokOkziFDF <module 'time' (built-in)>
# 0.0 RT @TomFitton: Deep State opposes @RealDonaldTrump.  https://t.co/pFDOXKrwsO <module 'time' (built-in)>
# 0.4215 RT @southernkimmy: Donald Trump MAGA hat powerful political symbol - The Washington Times https://t.co/zpg08Qd2Sc <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# -0.6908 RT @AndyOstroy: Things @realDonaldTrump has yet to comment on...
#
# *Coast Guard terrorist #PaulHasson
# *Historic North Carolina election-frau... <module 'time' (built-in)>
# -0.34 @realDonaldTrump Your flop sweat is very unbecoming of a @POTUS. <module 'time' (built-in)>
# 0.0 @DavidNiles6 @itsJeffTiedrich @realDonaldTrump Less than HRC gave up in her thousands of classified emails! <module 'time' (built-in)>
# -0.8885 RT @sirDukeDevin: Only in Trump's bastardized version of America would someone who lied about getting dirt from a foreign enemy even consid... <module 'time' (built-in)>
# 0.0 RT @davidaxelrod: Half century later, @realDonaldTrump finally is headed to Vietnam in the service of his country! <module 'time' (built-in)>
# 0.579 @realDonaldTrump NO..WE DONT! ALREADY INVESTIGATED! NOT GUILTY OF ANYTHING! MEANWHILE THE INDICTMENTS OF YOUR COHOR... https://t.co/V5OF1LKqmh <module 'time' (built-in)>
# 0.0 Cuz all he can pitch are shitballs <module 'time' (built-in)>
# 0.0 This is @AOC
# This is @SenSanders
# This is #socialism <module 'time' (built-in)>
# -0.5574 RT @charliekirk11: Obama said these are "dangerous times"
#
# He is lying, again
#
# Facts:
#
# Thanks to
# @realDonaldTrump
#  world has never been s... <module 'time' (built-in)>
# -0.5994 RT @BatmanisElvis: @LaylaAlisha11 @AlexCornitius President Trump commands the military &amp; Patriots all own guns so this coup &amp; civil war wil... <module 'time' (built-in)>
# 0.34 RT @NicolasMaduro: Trataron de tapar con un concierto y una supuesta "ayuda humanitaria" en la frontera, un plan que ha sido develado y anu... <module 'time' (built-in)>
# 0.0 @realDonaldTrump @ilduce2016 https://t.co/peULAw6ILp <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# 0.0 RT @davidaxelrod: Half century later, @realDonaldTrump finally is headed to Vietnam in the service of his country! <module 'time' (built-in)>
# 0.0 RT @RobertoCarlo14: Para los que me han preguntado:
#
# Creo que la salida final sera un ultimatum publico d USA pero a traves de Donald Trump... <module 'time' (built-in)>
# 0.6486 Thank you @realDonaldTrump  for your tireless work protecting The People of The United States <module 'time' (built-in)>
# 0.0 @itsJeffTiedrich @realDonaldTrump While you are focussing on the irrelevant, how about saluting your president for... https://t.co/PHRRUuKS04 <module 'time' (built-in)>
# 0.0 RT @SnakeOilPrez: Donald Trump wanted a military parade and had to settle for a fireworks display that already existed.
#
# Kinda reminds me... <module 'time' (built-in)>
# ...
# 0.0 RT @davidaxelrod: Half century later, @realDonaldTrump finally is headed to Vietnam in the service of his country! <module 'time' (built-in)>
# -0.3612 RT @ProudResister: -- A Trump supporter says he "might have to kill" a black man.
#
# -- A Trump supporter calls female protestors "fuckin' whor... <module 'time' (built-in)>
# -0.296 @slafam1 @JudicialWatch Oh stop I know President Trump personally u don't even know. Him u sit behind ur computer a... https://t.co/re3O1I4VCE <module 'time' (built-in)>
# 0.0 RT @TrumpKAG: @realDonaldTrump Kanye and Kid Rock need to be the headliners for the Salute to America concert right before President Trump... <module 'time' (built-in)>
# 0.0 RT @TrumpOrBust2020: Trump said on Feb. 24 he would delay an increase in U.S. tariffs on Chinese goods scheduled for later this week thanks... <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/TOXaK7W7X9 <module 'time' (built-in)>
# -0.5267 @Book_Em_Dano_83 @Joseph_D_Rucker @davidaxelrod @realDonaldTrump And so what if?
#
# Did they plot out a conspiracy a... https://t.co/PAXM56Ezmb <module 'time' (built-in)>
# 0.0 RT @LisaMei62: His perp walk can't come soon enough. https://t.co/Mxtbq7cHDX <module 'time' (built-in)>
# 0.6369 RT @myyaya7: Love their reactions  #WWG1WGA #MAGA #KAG2020 @realDonaldTrump @POTUS #TWGRP https://t.co/9XywLcKe3r <module 'time' (built-in)>
# 0.946 RT @PinkBelgium:  Huge Congratulations To Our Friend @KayaJones For Winning A GRAMMY Award. You Are The Voice of The @realDonaldTrump's Su... <module 'time' (built-in)>
# 0.4767 @realDonaldTrump I'm pretty sure they've been doing this fireworks display for a pretty long time.. hell I remember... https://t.co/Mmwbr3h4ZU <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# -0.6249 RT @SecPompeo: Spoke to @JakeTapper on @CNNSotu today. We discussed the Venezuela crisis and, in advance of the Hanoi Summit, @realDonaldTr... <module 'time' (built-in)>
# 0.0 RT @TomFitton: Will @AdamSchiff testify about his  and his party's "collusion" with Fusion GPS to overthrow @RealDonaldTrump?  https://t.co... <module 'time' (built-in)>
# 0.0 RT @PacificReports: @realDonaldTrump https://t.co/aPAKvUnN8z <module 'time' (built-in)>
# 0.0 @JudicialWatch @realDonaldTrump LOCK OBAMA UP! <module 'time' (built-in)>
# 0.0 He should, but I think not!!! <module 'time' (built-in)>
# -0.2755 RT @MSNBC: Former CIA Director John Brennan: "Mr.Trump is a deeply flawed individual, who I think has demonstrated that he is not fit to se... <module 'time' (built-in)>
# 0.25 RT @Fahrenthold: Read @tparti on the second gathering of the "Trumpettes," who were created to fill the holes in Mar-a-Lago's social calend... <module 'time' (built-in)>
# 0.0 He must have a make-up team accompany whereever he goes. <module 'time' (built-in)>
# -0.7506 RT @KAG4All: TAXATION WITHOUT REPRESENTATION
# Why do voters continually re-elect these anti-American lying politicians?
# We are forced to pay... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.5859 RT @DoingRight1: Are you sure you want Socialism? The far left can be helping Donald Trump get re-elected with their radical views.  Can yo... <module 'time' (built-in)>
# 0.0129 RT @jacobsoboroff: Safe to say these were a giant waste of money.
#
# None of the designs were picked or will ever be built.
#
# But at least Tr... <module 'time' (built-in)>
# 0.6695 RT @GroundsGalen123: SO URGENT! 7PM PRESIDENT TRUMP BREAKING NEWS TODAY 2/24/19 https://t.co/SouthXUBHx via @YouTube <module 'time' (built-in)>
# 0.2732 RT @Baba9773: 16) these other agreements doesn't mean anything --
#
# AMBASSADOR LIGHTHIZER: We're never using that word again.
#
# PRESIDENT TRUM... <module 'time' (built-in)>
# 0.0 RT @Dennis17Viper: Keep going indeed..... https://t.co/LTeSS3ottp <module 'time' (built-in)>
# -0.5932 RT @Education4Libs: Dear libs,
#
# I don't remember congressional approval for the $1.7 billion Obama sent to a country that chants "death to... <module 'time' (built-in)>
# 0.0 RT @JohnFugelsang: Guys Donald Trump just decreed that this year's 4th of July may also be referred to as Independence Day.
#
# He's also go... <module 'time' (built-in)>
# 0.4435 RT @StumpforTrump: GREAT AGAIN: @realDonaldTrump Just Scored A MAJOR Victory With China, But The Media Is Staying Quiet https://t.co/Rc2Z0i... <module 'time' (built-in)>
# 0.0 Trump sees 'very big news' in China trade talks in next week or two: U.S. President Donald Trump said on Sunday tha... https://t.co/fhszzkEHm5 <module 'time' (built-in)>
# 0.0 @djanko112 @worldmeetjohn @debrastewart841 @JoshShaffer2030 @ChatByCC @realDonaldTrump But now Putin is threatening... https://t.co/j1qiyykpLW <module 'time' (built-in)>
# 0.3818 RT @thebradfordfile: While Democrats focus on the faux Russian 'threat'--President Trump is focused on the country that has been robbing us... <module 'time' (built-in)>
# -0.4588 RT @EdKrassen: "I personally witnessed the Plaintiff being forced to perform various sexual acts with Donald J. Trump and Mr. Epstein. Both... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# -0.6808 RT @JeffreyGuterman: @realDonaldTrump I believe you raped a child. Katie Johnson said: Before I gave him a handjob, he kind of slapped my h... <module 'time' (built-in)>
# -0.765 RT @PrisonPlanet: When right-wingers said this about Obama, they were lambasted as lunatic conspiracy theorists. Now it's on CNN. https://t... <module 'time' (built-in)>
# -0.6124 RT @EdKrassen: @realDonaldTrump Republican Governor of South Dakota, Kristi Noem told Politico that, "South Dakota has been devastated by t... <module 'time' (built-in)>
# 0.4404 RT @AngrierWHStaff: Watching people who used to have good reputations throw them away for Donald Trump is still incredible to me.
#
# Admitted... <module 'time' (built-in)>
# -0.6012 RT @Xeryus6: @CharlesARodrig2 You are messing around with the wrong guy governor Rossello don't challenge @realDonaldTrump playing the dirt... <module 'time' (built-in)>
# -0.5574 RT @perlmutations: There's gotta be 60 million of us who can afford a buck each to stick some shit under this piece of shit's nose.
#
# I'm s... <module 'time' (built-in)>
# 0.0 RT @FairTaxOfficial: It really is this simple. @realDonaldTrump
# @mike_pence
# Go for it in 2020.
# #FAIRtax https://t.co/oniZfHNBG2 <module 'time' (built-in)>
# 0.0 RT @Fahrenthold: This is at least the 2nd time @realDonaldTrump has recorded a video for a Mar-a-Lago banquet. He also did it for the PB Po... <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.6597 RT @UROCKlive1: @realDonaldTrump @KatiePavlich That's funny. I live in the suburbs &amp; women are continuing to leave the Republican Party in... <module 'time' (built-in)>
# -0.1926 RT @kylegriffin1: NYT Editorial Board: "The Constitution or The Donald? Why is this such a hard choice for congressional Republicans?"
# http... <module 'time' (built-in)>
# 0.0 @EdKrassen @realDonaldTrump Ed and his brother are paid to comment negatively on every trump post. Do the research... https://t.co/PJwSDuDPUe <module 'time' (built-in)>
# 0.0 RT @BolsonaroSP: Inesperadamente fui chamado pela anfitria Toni Kramer, uma das maiores apoiadoras de @realDonaldTrump nos EUA, para fala... <module 'time' (built-in)>
# 0.1511 RT @saradannerdukic: Speaking of trafficking, remember how Trump brought teens over without papers, then charged them so much for their bun... <module 'time' (built-in)>
# 0.0 RT @DaveWeasel: @realDonaldTrump Everyone who clicks "maybe" is actually saying "no". <module 'time' (built-in)>
# 0.0 RT @jb_anon: Q-Drop 2814/2815
# Decode
#
# ODNI and NSA Impeded Lawmakers Review of Obama Admin "Unmasking" Requests!
#
# Discretion Must Be Applie... <module 'time' (built-in)>
# -0.6808 RT @RyanAFournier: Time to hear all of the Hollywood elite complain about how oppressed they are under President Trump.  #TheOscars <module 'time' (built-in)>
# 0.1531 RT @miababy37: I'd just like to know why people are celebrating this? This means no sex education, no birth control &amp; condoms which stop ab... <module 'time' (built-in)>
# 0.0 @realDonaldTrump https://t.co/zA9UvW4LnJ <module 'time' (built-in)>
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# C:\ProgramData\Anaconda3\lib\site-packages\OpenSSL\SSL.py in _raise_ssl_error(self, ssl, result)
#    1613         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1614             raise WantReadError()
#    1615         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-393ff1dbe118> in <module>()
#      32         auth.set_access_token(access_token_key, access_token_secret)
#      33         twitterStream = Stream(auth, listener())
# ---> 34         twitterStream.filter(track=["@realDonaldTrump", "Donald Trump", "President Trump"])
#      35         # Avoid only using 'trump' to avoid overfitting, i.e. ace trump etc.
#      36
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# C:\ProgramData\Anaconda3\lib\http\client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# C:\ProgramData\Anaconda3\lib\http\client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# C:\ProgramData\Anaconda3\lib\socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in select(self, timeout)
#     318             ready = []
#     319             r, w, _ = _syscall_wrapper(self._select, True, self._readers,
# --> 320                                        self._writers, timeout)
#     321             r = set(r)
#     322             w = set(w)
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# C:\ProgramData\Anaconda3\lib\site-packages\urllib3\util\selectors.py in _select(self, r, w, timeout)
#     308         def _select(self, r, w, timeout=None):
#     309             """ Wrapper for select.select because timeout is a positional arg """
# --> 310             return select.select(r, w, [], timeout)
#     311
#     312         def select(self, timeout=None):
#
# KeyboardInterrupt:
